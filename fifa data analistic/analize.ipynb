# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv('data.csv')
df.shape
# Out:
# (18541, 73)

# %%
df.head()
# Out:
#    id1  id      ID                   Nom  Age    Nationalité  General  \
# 0    0   0  253283     Facundo Pellistri   18        Uruguay       71
# 1    1   1  179813        Edinson Cavani   32        Uruguay       86
# 2    2   2  245541        Giovanni Reyna   17  United States       68
# 3    3   3  233419  Raphael Dias Belloli   23         Brazil       81
# 4    4   4  198710       James Rodríguez   28       Colombia       82
#
#    Potentiel                 Club Pied prefrere  ... Penalties Composure  \
# 0         87              Peñarol         Right  ...      66.0      61.0
# 1         86  Paris Saint-Germain         Right  ...      85.0      80.0
# 2         87    Borussia Dortmund         Right  ...      50.0      59.0
# 3         85     Stade Rennais FC          Left  ...      73.0      79.0
# 4         82              Everton          Left  ...      81.0      87.0
#
#   Defensive Awareness Standing Tackle Sliding Tackle GK Diving GK Handling  \
# 0                35.0            11.0           18.0       9.0        12.0
# 1                57.0            48.0           39.0      12.0         5.0
# 2                30.0            23.0           24.0      10.0        13.0
# 3                45.0            54.0           38.0       8.0         7.0
# 4                52.0            41.0           44.0      15.0        15.0
#
#   GK Kicking GK Positioning GK Reflexes
# 0        7.0            8.0         7.0
# 1       13.0           13.0        10.0
# 2       14.0           12.0         7.0
# 3       13.0            8.0        14.0
# 4       15.0            5.0        14.0
#
# [5 rows x 73 columns]

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18541 entries, 0 to 18540
# Data columns (total 73 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id1                  18541 non-null  int64
#  1   id                   18541 non-null  int64
#  2   ID                   18541 non-null  int64
#  3   Nom                  18541 non-null  object
#  4   Age                  18541 non-null  int64
#  5   Nationalité          18541 non-null  object
#  6   General              18541 non-null  int64
#  7   Potentiel            18541 non-null  int64
#  8   Club                 18170 non-null  object
#  9   Pied prefrere        18541 non-null  object
#  10  Taille               18541 non-null  object
#  11  Poid                 18541 non-null  object
#  12  LS                   16757 non-null  object
#  13  ST                   16757 non-null  object
#  14  RS                   16757 non-null  object
#  15  LW                   16757 non-null  object
#  16  LF                   16757 non-null  object
#  17  CF                   16757 non-null  object
#  18  RF                   16757 non-null  object
#  19  RW                   16757 non-null  object
#  20  LAM                  16757 non-null  object
#  21  CAM                  16757 non-null  object
#  22  RAM                  16757 non-null  object
#  23  LM                   16757 non-null  object
#  24  LCM                  16757 non-null  object
#  25  CM                   16757 non-null  object
#  26  RCM                  16757 non-null  object
#  27  RM                   16757 non-null  object
#  28  LWB                  16757 non-null  object
#  29  LDM                  16757 non-null  object
#  30  CDM                  16757 non-null  object
#  31  RDM                  16757 non-null  object
#  32  RWB                  16757 non-null  object
#  33  LB                   16757 non-null  object
#  34  LCB                  16757 non-null  object
#  35  CB                   16757 non-null  object
#  36  RCB                  16757 non-null  object
#  37  RB                   16757 non-null  object
#  38  GK                   16757 non-null  object
#  39  Crossing             18388 non-null  float64
#  40  Finishing            18332 non-null  float64
#  41  Heading Accuracy     18408 non-null  float64
#  42  Short Passing        18321 non-null  float64
#  43  Volleys              18378 non-null  float64
#  44  Dribbling            18358 non-null  float64
#  45  Curve                18421 non-null  float64
#  46  FK Accuracy          18497 non-null  float64
#  47  Long Passing         18403 non-null  float64
#  48  Ball Control         18327 non-null  float64
# std          21.486975       21.175411     16.863310     16.177023
# min           5.000000        6.000000      1.000000      1.000000
# 10%          16.000000       15.000000      6.000000      6.000000
# 25%          28.000000       25.000000      8.000000      8.000000
# 50%          55.000000       52.000000     11.000000     11.000000
# 75%          66.000000       64.000000     14.000000     14.000000
# 90%          73.000000       71.000000     16.000000     16.000000
# max          93.000000       95.000000     90.000000     92.000000
#
#          GK Kicking  GK Positioning   GK Reflexes
# count  18509.000000    18507.000000  18505.000000
# mean      15.552596       15.565246     15.802864
# std       16.039980       16.401177     17.134275
# min        1.000000        1.000000      1.000000
# 10%        6.000000        6.000000      6.000000
# 25%        8.000000        8.000000      8.000000
# 50%       11.000000       11.000000     11.000000
# 75%       14.000000       14.000000     14.000000
# 90%       16.000000       16.000000     16.000000
# max       93.000000       93.000000     90.000000
#
# [10 rows x 40 columns]

# %%
df.columns
# Out:
# Index(['id1', 'id', 'ID', 'Nom', 'Age', 'Nationalité', 'General', 'Potentiel',
#        'Club', 'Pied prefrere', 'Taille', 'Poid', 'LS', 'ST', 'RS', 'LW', 'LF',
#        'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM',
#        'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'GK',
#        'Crossing', 'Finishing', 'Heading Accuracy', 'Short Passing', 'Volleys',
#        'Dribbling', 'Curve', 'FK Accuracy', 'Long Passing', 'Ball Control',
#        'Acceleration', 'Sprint Speed', 'Agility', 'Reactions', 'Balance',
#        'Shot Power', 'Jumping', 'Stamina', 'Strength', 'Long Shots',
#        'Aggression', 'Interceptions', 'Positioning', 'Vision', 'Penalties',
#        'Composure', 'Defensive Awareness', 'Standing Tackle', 'Sliding Tackle',
#        'GK Diving', 'GK Handling', 'GK Kicking', 'GK Positioning',
#        'GK Reflexes'],
#       dtype='object')

# %%
df['General'].plot.density()
# Out:
# <AxesSubplot: ylabel='Density'>

# %%
df['Potentiel'].plot.hist(bins=25,figsize=(8,4))
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
df.corr()
# Out:
# C:\Users\Adame\AppData\Local\Temp\ipykernel_13296\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                           id1        id        ID       Age   General  \
# id1                  1.000000  1.000000 -0.104625  0.145874 -0.445338
# id                   1.000000  1.000000 -0.104625  0.145874 -0.445338
# ID                  -0.104625 -0.104625  1.000000 -0.740295 -0.425691
# Age                  0.145874  0.145874 -0.740295  1.000000  0.517018
# General             -0.445338 -0.445338 -0.425691  0.517018  1.000000
# Potentiel           -0.656116 -0.656116  0.042908 -0.233716  0.595419
# Crossing            -0.207610 -0.207610 -0.151160  0.150701  0.389336
# Finishing           -0.202988 -0.202988 -0.107368  0.105825  0.307623
# Heading Accuracy    -0.143145 -0.143145 -0.150551  0.177498  0.311461
# Short Passing       -0.279910 -0.279910 -0.168807  0.175092  0.494138
# Volleys             -0.197926 -0.197926 -0.205656  0.187432  0.364662
# Dribbling           -0.264130 -0.264130 -0.059579  0.039915  0.353918
# Curve               -0.224542 -0.224542 -0.197586  0.180353  0.402672
# FK Accuracy         -0.156693 -0.156693 -0.233911  0.224158  0.374459
# Long Passing        -0.229980 -0.229980 -0.211982  0.222514  0.484674
# Ball Control        -0.273145 -0.273145 -0.132406  0.120551  0.434938
# Acceleration        -0.205783 -0.205783  0.163605 -0.182639  0.151869
# Sprint Speed        -0.206711 -0.206711  0.167234 -0.177152  0.161658
# Agility             -0.198495 -0.198495  0.019550 -0.039238  0.233989
# Reactions           -0.378138 -0.378138 -0.414643  0.497815  0.868021
# Balance             -0.129912 -0.129912  0.042365 -0.086289  0.105360
# Shot Power          -0.262101 -0.262101 -0.272803  0.301162  0.534642
# Jumping             -0.086151 -0.086151 -0.147340  0.200400  0.264377
# Stamina             -0.184154 -0.184154  0.012828  0.072964  0.338881
# GK Kicking           -0.006019 -0.632860  -0.563351         -0.701821
# GK Positioning       -0.008533 -0.645618  -0.574136         -0.712887
# GK Reflexes          -0.011295 -0.648893  -0.576393         -0.717375
#
#                      Short Passing  ...  Penalties  Composure  \
# id1                      -0.279910  ...  -0.150245  -0.344605
# id                       -0.279910  ...  -0.150245  -0.344605
# ID                       -0.168807  ...  -0.217623  -0.416376
# Age                       0.175092  ...   0.198634   0.418508
# General                   0.494138  ...   0.322538   0.704367
# Potentiel                 0.320321  ...   0.153030   0.370485
# Crossing                  0.802131  ...   0.639252   0.600893
# Finishing                 0.658495  ...   0.838650   0.568544
# Heading Accuracy          0.639200  ...   0.542176   0.531032
# Short Passing             1.000000  ...   0.671252   0.730044
# Volleys                   0.689188  ...   0.841860   0.626383
# Dribbling                 0.845048  ...   0.760381   0.642538
# Curve                     0.769569  ...   0.751862   0.649568
# FK Accuracy               0.723979  ...   0.734221   0.609319
# Long Passing              0.887108  ...   0.528813   0.682176
# Ball Control              0.916554  ...   0.764705   0.712811
# Acceleration              0.520975  ...   0.480267   0.337471
# Sprint Speed              0.508591  ...   0.467222   0.333276
# Agility                   0.582725  ...   0.531631   0.438520
# Reactions                 0.493477  ...   0.343520   0.690568
# Balance                   0.525408  ...   0.461222   0.337522
# Shot Power                0.590929  ...   0.687530   0.628891
# Jumping                   0.180815  ...   0.105797   0.246294
# Stamina                   0.693824  ...   0.466920   0.527195
# Strength                  0.141452  ...   0.074051   0.277315
# Long Shots                0.755767  ...   0.815623   0.651261
# Aggression                0.613111  ...   0.327484   0.540212
# Interceptions             0.535486  ...   0.073572   0.397085
# Positioning               0.758167  ...   0.806457   0.622450
# Vision                    0.709521  ...   0.633301   0.667162
# Penalties                 0.671252  ...   1.000000   0.591243
# Composure                 0.730044  ...   0.591243   1.000000
# Defensive Awareness       0.571163  ...   0.108953   0.413975
# Standing Tackle           0.534244  ...   0.063335   0.356417
# Sliding Tackle            0.499968  ...   0.023949   0.320762
# GK Diving                -0.720184  ...  -0.598094  -0.405196
# GK Handling              -0.718879  ...  -0.595003  -0.403675
# GK Kicking               -0.702304  ...  -0.572118  -0.402835
# GK Positioning           -0.713902  ...  -0.592437  -0.397041
# GK Reflexes              -0.719751  ...  -0.595960  -0.405003
#
#                      Defensive Awareness  Standing Tackle  Sliding Tackle  \
# id1                            -0.128539        -0.102757       -0.089183
# id                             -0.128539        -0.102757       -0.089183
# ID                             -0.141794        -0.072625       -0.056909
# Age                             0.165448         0.107920        0.088251
# General                         0.303523         0.240288        0.213117
# Potentiel                       0.152734         0.139364        0.130999
# Crossing                        0.433199         0.404252        0.384063
# Finishing                      -0.004130        -0.059397       -0.099700
# Heading Accuracy                0.560467         0.528899        0.502035
# Short Passing                   0.571163         0.534244        0.499968
# Volleys                         0.082651         0.030620       -0.009396
# Dribbling                       0.329556         0.286783        0.258397
# Curve                           0.277257         0.236528        0.205011
# FK Accuracy                     0.277677         0.244446        0.211160
# Long Passing                    0.605579         0.583818        0.559723
# Ball Control                    0.446372         0.399685        0.365140
# Acceleration                    0.156102         0.122148        0.116284
# Sliding Tackle       -0.472048    -0.472207   -0.473062       -0.468536
# GK Diving             1.000000     0.967036    0.947210        0.966654
# GK Handling           0.967036     1.000000    0.953579        0.967457
# GK Kicking            0.947210     0.953579    1.000000        0.952967
# GK Positioning        0.966654     0.967457    0.952967        1.000000
# GK Reflexes           0.970220     0.968355    0.953567        0.967870
#
#                      GK Reflexes
# id1                     0.056876
# id                      0.056876
# ID                     -0.087110
# Age                     0.115057
# General                 0.028121
# Potentiel              -0.011295
# Crossing               -0.648893
# Finishing              -0.576393
# Heading Accuracy       -0.717375
# Short Passing          -0.719751
# Volleys                -0.573478
# Dribbling              -0.752308
# Curve                  -0.592623
# FK Accuracy            -0.531246
# Long Passing           -0.567708
# Ball Control           -0.783000
# Acceleration           -0.564520
# Sprint Speed           -0.570370
# Agility                -0.504424
# Reactions              -0.028392
# Balance                -0.487995
# Shot Power             -0.301915
# Jumping                -0.151403
# Stamina                -0.656577
# Strength               -0.086722
# Long Shots             -0.593686
# Aggression             -0.550336
# Interceptions          -0.446862
# Positioning            -0.666669
# Vision                 -0.352056
# Penalties              -0.595960
# Composure              -0.405003
# Defensive Awareness    -0.506290
# Standing Tackle        -0.494773
# Sliding Tackle         -0.473828
# GK Diving               0.970220
# GK Handling             0.968355
# GK Kicking              0.953567
# GK Positioning          0.967870
# GK Reflexes             1.000000
#
# [40 rows x 40 columns]

# %%
df.drop(['id1','id','ID','Nom','Age','Nationalité','Club','Pied prefrere','Taille','Poid','LS','ST','RS','LW','LF','CF','RF','RW','LAM','CAM','RAM','LM','LCM','CM','RCM','RM','LWB','LDM','CDM','RDM','RWB','LB','LCB','CB','RCB','RB','GK'],axis=1, inplace=True)
df.head()
# Out:
#    General  Potentiel  Crossing  Finishing  Heading Accuracy  Short Passing  \
# 0       71         87      67.0       60.0              50.0           67.0
# 1       86         86      68.0       87.0              89.0           75.0
# 2       68         87      54.0       59.0              42.0           73.0
# 3       81         85      76.0       72.0              45.0           74.0
# 4       82         82      90.0       84.0              62.0           83.0
#
#    Volleys  Dribbling  Curve  FK Accuracy  ...  Penalties  Composure  \
# 0     56.0       74.0   59.0         62.0  ...       66.0       61.0
# 1     88.0       75.0   75.0         76.0  ...       85.0       80.0
# 2     59.0       77.0   74.0         64.0  ...       50.0       59.0
# 3     72.0       84.0   81.0         72.0  ...       73.0       79.0
# 4     90.0       86.0   89.0         86.0  ...       81.0       87.0
#
#    Defensive Awareness  Standing Tackle  Sliding Tackle  GK Diving  \
# 0                 35.0             11.0            18.0        9.0
# 1                 57.0             48.0            39.0       12.0
# 2                 30.0             23.0            24.0       10.0
# 3                 45.0             54.0            38.0        8.0
# 4                 52.0             41.0            44.0       15.0
#
#    GK Handling  GK Kicking  GK Positioning  GK Reflexes
# 0         12.0         7.0             8.0          7.0
# 1          5.0        13.0            13.0         10.0
# 2         13.0        14.0            12.0          7.0
# 3          7.0        13.0             8.0         14.0
# 4         15.0        15.0             5.0         14.0
#
# [5 rows x 36 columns]

# %%
plt.figure(figsize=(10,7))
sns.heatmap(df.corr(),annot=True,linewidths=2)
# Out:
# <AxesSubplot: >

# %%
df.drop(['Potentiel'],axis=1, inplace=True)
l_column = list(df.columns)
len_feature = len(l_column)  
l_column
# Out:
# ['General',
#  'Crossing',
#  'Finishing',
#  'Heading Accuracy',
#  'Short Passing',
#  'Volleys',
#  'Dribbling',
#  'Curve',
#  'FK Accuracy',
#  'Long Passing',
#  'Ball Control',
#  'Acceleration',
#  'Sprint Speed',
#  'Agility',
#  'Reactions',
#  'Balance',
#  'Shot Power',
#  'Jumping',
#  'Stamina',
#  'Strength',
#  'Long Shots',
#  'Aggression',
#  'Interceptions',
#  'Positioning',
#  'Vision',
#  'Penalties',
#  'Composure',
#  'Defensive Awareness',
#  'Standing Tackle',
#  'Sliding Tackle',
#  'GK Diving',
#  'GK Handling',
#  'GK Kicking',
#  'GK Positioning',
#  'GK Reflexes']

# %%
X = df[l_column[0:len_feature]]
y = df[l_column[len_feature-35]]

print("Taille de l'ensemble des fonctionnalités :",X.shape)
print("Taille de l'ensemble des variables:",y.shape)
# Out:
# Taille de l'ensemble des fonctionnalités : (18541, 35)
# Taille de l'ensemble des variables: (18541,)

# %%
X.head()
# Out:
#    General  Crossing  Finishing  Heading Accuracy  Short Passing  Volleys  \
# 0       71      67.0       60.0              50.0           67.0     56.0
# 1       86      68.0       87.0              89.0           75.0     88.0
# 2       68      54.0       59.0              42.0           73.0     59.0
# 3       81      76.0       72.0              45.0           74.0     72.0
# 4       82      90.0       84.0              62.0           83.0     90.0
#
#    Dribbling  Curve  FK Accuracy  Long Passing  ...  Penalties  Composure  \
# 0       74.0   59.0         62.0          58.0  ...       66.0       61.0
# 1       75.0   75.0         76.0          52.0  ...       85.0       80.0
# 2       77.0   74.0         64.0          50.0  ...       50.0       59.0
# 3       84.0   81.0         72.0          66.0  ...       73.0       79.0
# 4       86.0   89.0         86.0          81.0  ...       81.0       87.0
#
#    Defensive Awareness  Standing Tackle  Sliding Tackle  GK Diving  \
# 0                 35.0             11.0            18.0        9.0
# 1                 57.0             48.0            39.0       12.0
# 2                 30.0             23.0            24.0       10.0
# 3                 45.0             54.0            38.0        8.0
# 4                 52.0             41.0            44.0       15.0
#
#    GK Handling  GK Kicking  GK Positioning  GK Reflexes
# 0         12.0         7.0             8.0          7.0
# 1          5.0        13.0            13.0         10.0
# 2         13.0        14.0            12.0          7.0
# 3          7.0        13.0             8.0         14.0
# 4         15.0        15.0             5.0         14.0
#
# [5 rows x 35 columns]

# %%
y.head()
# Out:
# 0    71
# 1    86
# 2    68
# 3    81
# 4    82
# Name: General, dtype: int64

# %%
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=123)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (12978, 35)
# (5563, 35)
# (12978,)
# (5563,)

# %%
lr= LinearRegression()
X_train = X_train.replace((np.inf, -np.inf, np.nan), 0).reset_index(drop=True)

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lr.intercept_
# Out:
# 1.2221335055073723e-12

# %%
lr.coef_
# Out:
# array([ 1.00000000e+00,  6.53943965e-16,  1.62576398e-16,  1.04378029e-15,
#        -1.73896261e-15, -4.43867512e-16,  1.23993290e-15,  1.75444080e-15,
#         3.82170584e-16, -1.34292876e-16, -3.37184548e-16, -7.03267544e-16,
#        -3.96141729e-16,  4.96590976e-16, -2.25873346e-16, -1.55646332e-16,
#        -4.62335927e-16, -3.66048399e-16,  7.72805127e-16,  4.29442202e-16,
#        -1.45054480e-15, -7.79725476e-17, -1.51495828e-15,  3.09954415e-16,
#         6.21752647e-16, -1.63704785e-15,  1.19717580e-16,  4.87297193e-17,
#         2.47553886e-15, -2.02288442e-15, -1.22836270e-15, -6.02262162e-16,
#        -3.75865753e-16,  1.02829701e-15,  1.12488092e-15])

# %%
cdf = pd.DataFrame(data=lr.coef_, index=X_train.columns, columns=["Coefficients"])
cdf
# Out:
#                      Coefficients
# General              1.000000e+00
# Crossing             6.539440e-16
# Finishing            1.625764e-16
# Heading Accuracy     1.043780e-15
# Short Passing       -1.738963e-15
# Volleys             -4.438675e-16
# Dribbling            1.239933e-15
# Curve                1.754441e-15
# FK Accuracy          3.821706e-16
# Long Passing        -1.342929e-16
# Ball Control        -3.371845e-16
# Acceleration        -7.032675e-16
# Sprint Speed        -3.961417e-16
# Agility              4.965910e-16
# Reactions           -2.258733e-16
# Balance             -1.556463e-16
# Shot Power          -4.623359e-16
# Jumping             -3.660484e-16
# Stamina              7.728051e-16
# Strength             4.294422e-16
# Long Shots          -1.450545e-15
# Aggression          -7.797255e-17
# Interceptions       -1.514958e-15
# Positioning          3.099544e-16
# Vision               6.217526e-16
# Penalties           -1.637048e-15
# Composure            1.197176e-16
# Defensive Awareness  4.872972e-17
# Standing Tackle      2.475539e-15
# Sliding Tackle      -2.022884e-15
# GK Diving           -1.228363e-15
# GK Handling         -6.022622e-16
# GK Kicking          -3.758658e-16
# GK Positioning       1.028297e-15
# GK Reflexes          1.124881e-15

# %%
l=list(cdf.index)
from matplotlib import gridspec
fig = plt.figure(figsize=(18, 10))
gs = gridspec.GridSpec(2,3)
 
ax0 = plt.subplot(gs[0])
ax0.scatter(df[l[0]],df['General'])
ax0.set_title(l[0]+" vs. general", fontdict={'fontsize':20})

ax1 = plt.subplot(gs[1])
ax1.scatter(df[l[1]],df['General'])
ax1.set_title(l[1]+" vs. General",fontdict={'fontsize':20})

ax2 = plt.subplot(gs[2])
ax2.scatter(df[l[2]],df['General'])
ax2.set_title(l[2]+" vs.General",fontdict={'fontsize':20})

ax3 = plt.subplot(gs[3])
ax3.scatter(df[l[3]],df['General'])
ax3.set_title(l[3]+" vs.General",fontdict={'fontsize':20})

ax4 = plt.subplot(gs[4])
ax4.scatter(df[l[4]],df['General'])
ax4.set_title(l[4]+" vs. General",fontdict={'fontsize':20})
# Out:
# Text(0.5, 1.0, 'Short Passing vs. General')

# %%
train_pred=lr.predict(X_train)
round(metrics.r2_score(y_train,train_pred),3)
# Out:
# 1.0

# %%
X_test=X_test.replace((np.inf, -np.inf, np.nan), 0).reset_index(drop=True)
predictions=lr.predict(X_test)
plt.figure(figsize=(10,7))
plt.scatter(x=y_test,y=predictions)

# %%
plt.figure(figsize=(10,7))
plt.title("Histogram of residuals to check for normality",fontsize=25)
plt.xlabel("Residuals",fontsize=18)
plt.ylabel("Kernel density", fontsize=18)
sns.distplot([y_test-predictions])
# Out:
# C:\Users\Adame\AppData\Local\Temp\ipykernel_13296\1562080281.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot([y_test-predictions])
# <AxesSubplot: title={'center': 'Histogram of residuals to check for normality'}, xlabel='Residuals', ylabel='Kernel density'>

# %%
print(round(metrics.r2_score(y_test,predictions),3))
# Out:
# R-squared value of predictions: 1.0
